# %% [markdown]
# Databases
# =====================
#
# ********************
#
# 3DMM
# ---------------
# ##  * Surrey Face Model !
#
# [[paper]](http://epubs.surrey.ac.uk/809478/1/Huber-VISAPP-2016.pdf)[[github]](https://github.com/patrikhuber/eos)[[database]](http://www.cvssp.org/faceweb/3dmm/facemodel/)
#
# 1. **3D Morphable Model**
#  Shape S and Color(albedo) T
#  PCA model:
#   $$M:=(\overline{v},\sigma,V)$$
#  Novel face can be generated by:
#   $$S=\overline{v}+\sum_{i}^{M}{\alpha_i\sigma_iV_i}$$
#
# > Shape Model:
# > ![shape](images/databases/shape.png)
#
# > Color Model:
# > ![color](images/databases/color.png)
#
# 2. **3D Scan Data**
# >Age:
# 9 teens, 106 young adults, 33 adults, 13 matures, 8 seniors
# > Racial:
# ![racial](images/databases/scans.png)
#
# ### * Basel Face Model
# http://faces.cs.unibas.ch/bfm/main.php?nav=1-0&id=basel_face_model
# 53,490 3D vertices connected by 160,470 triangles.
# Faces of different identities can be composed as linear combinations of 199 principal components.
#
# The model is given by:
# The average shape
# The principal shape components
# The shape variance
# The mesh topology
# The average texture
# The principal texture components
# The texture variance
#
# ![mean shape](http://faces.cs.unibas.ch/bfm/content/basel_face_model/details//images/pc-shape.png)
# ![mean texture](http://faces.cs.unibas.ch/bfm/content/basel_face_model/details//images/pc-texture.png)
#
# we can get the face model(load 01_MorphableModel.mat)
# * shapeMU: The average shape
# * shapePC: The principal shape components
# * shapeEV: The shape variance
# * texMU: The average texture
# * texPC: The principal texture components
# * texEV: The texture variance
#
# Then, any 3D face can be expressed as:
#
# $ S_{model}=\overline{S}+\sum_{i=1}^{m-1}{\alpha_is_i} \ \ (1)$
#
# $ T_{model}=\overline{T}+\sum_{i=1}^{m-1}{\beta_it_i} \ \ (2)$
#
# __The problem__ is
# how to etismate $\alpha$ and $\beta$
#
# *********************
#
# 2D
# -----------------
#
# ### * CMU-PIE (common use）
#
# http://www.ri.cmu.edu/research_project_detail.html?project_id=418&menu_id=261
# > We call this database the CMU Pose, Illumination, and Expression (PIE) database.
#
#
# ** 41,368 images of 68 people.**
# * 13 different poses
# ![poses](http://www.ri.cmu.edu/images/projects/pie_p.jpg)
#
# * 43 different illumination conditions
# ![illuminations](images/databases/illumination.png,)
#
# * 4 different expressions
# ![expressions](http://www.ri.cmu.edu/images/projects/pie_e.jpg)
#
#
# ### * FERET (common use)
# http://www.itl.nist.gov/iad/humanid/feret/feret_master.html
# gray-scale vison: http://www.itl.nist.gov/iad/humanid/feret/ (not available now)
# color-scale vision: https://www.nist.gov/itl/iad/image-group/color-feret-database
# > The FERET database is a standard dataset used for facial recognition system evaluation
#
# ** 2,413 still facial images of 856 individuals. **
#
# * size: ~8.5G
#
#
#
#
# ### * USF Human ID 3D
#
# ### * Multi-PIE
#
# ### * FacePix(30)
